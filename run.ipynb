# %%
# !python llm.py
# Out:
# sk-45974c1519d04cffa918d8f942e7627e
# https://dashscope.aliyuncs.com/compatible-mode/v1
# content='你好！我是DeepSeek，由深度求索公司创造的AI助手。😊\n\n我是一个纯文本模型，擅长回答各种问题、协助处理文字工作、进行对话交流等。虽然我不支持多模态识别功能，但我可以帮你处理上传的文件，包括图像、txt、pdf、ppt、word、excel等格式，从中读取文字信息进行分析处理。\n\n我的特点包括：\n- 完全免费使用\n- 支持128K上下文长度\n- 具有联网搜索功能（需要手动开启）\n- 可以通过官方应用商店下载App使用\n\n我的知识截止到2024年7月，会尽我所能为你提供准确、有用的信息和帮助。有什么问题或者需要我协助的吗？我很乐意为你服务！✨' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 7, 'total_tokens': 159, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v3.2-exp', 'system_fingerprint': None, 'id': 'chatcmpl-6fc9c5af-54fa-4640-accd-7e9195804972', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--c4c05842-7356-42cb-aeb1-c883b89761d4-0' usage_metadata={'input_tokens': 7, 'output_tokens': 152, 'total_tokens': 159, 'input_token_details': {}, 'output_token_details': {}}
